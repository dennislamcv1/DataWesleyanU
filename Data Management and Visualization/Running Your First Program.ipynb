# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gapminder.csv")

# %%
df
# Out:
#                 country incomeperperson alcconsumption armedforcesrate  \
# 0           Afghanistan                           0.03            0.57
# 1               Albania         1915.00           7.29            1.02
# 2               Algeria         2231.99           0.69            2.31
# 3               Andorra        21943.34          10.17
# 4                Angola         1381.00           5.57            1.46
# ..                  ...             ...            ...             ...
# 208             Vietnam          722.81           3.91            1.09
# 209  West Bank and Gaza                                           5.94
# 210         Yemen, Rep.          610.36           0.20            2.32
# 211              Zambia          432.23           3.56            0.34
# 212            Zimbabwe          320.77           4.96            1.03
#
#     breastcancerper100th   co2emissions femaleemployrate hivrate  \
# 0                  26.80    75944000.00            25.60
# 1                  57.40   223747333.33            42.10
# 2                  23.50  2932108666.67            31.70    0.10
# 3
# 4                  23.10   248358000.00            69.40    2.00
# ..                   ...            ...              ...     ...
# 208                16.20  1425435000.00            67.60    0.40
# 209                         14241333.33            11.30
# 210                35.10   234864666.67            20.30
# 211                13.00   132025666.67            53.50   13.50
# 212                19.00   590219666.67            58.10   14.30
#
#     internetuserate lifeexpectancy oilperperson polityscore  \
# 0              3.65          48.67                        0
# 1             44.99          76.92                        9
# 2             12.50          73.13         0.42           2
# 3             81.00
# 4             10.00          51.09                       -2
# ..              ...            ...          ...         ...
# 208           27.85          75.18                       -7
# 209           36.42          72.83
# 210           12.35          65.49                       -2
# 211           10.12          49.03                        7
# 212           11.50          51.38                        1
#
#     relectricperperson suicideper100th employrate urbanrate
# 0                                 6.68      55.70     24.04
# 1               636.34            7.70      51.40     46.72
# 2               590.51            4.85      50.50     65.22
# 3                                 5.36                88.92
# 4               173.00           14.55      75.70     56.70
# ..                 ...             ...        ...       ...
# 208             302.73           11.65      71.00     27.84
# 209                                         32.00     71.90
# 210             130.06            6.27      39.00     30.64
# 211             168.62           12.02      61.00     35.42
# 212             297.88           13.91      66.80     37.34
#
# [213 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               213 non-null    object
#  1   incomeperperson       213 non-null    object
#  2   alcconsumption        213 non-null    object
#  3   armedforcesrate       213 non-null    object
#  4   breastcancerper100th  213 non-null    object
#  5   co2emissions          213 non-null    object
#  6   femaleemployrate      213 non-null    object
#  7   hivrate               213 non-null    object
#  8   internetuserate       213 non-null    object
#  9   lifeexpectancy        213 non-null    object
#  10  oilperperson          213 non-null    object
#  11  polityscore           213 non-null    object
#  12  relectricperperson    213 non-null    object
#  13  suicideper100th       213 non-null    object
#  14  employrate            213 non-null    object
#  15  urbanrate             213 non-null    object
# dtypes: object(16)
# memory usage: 26.8+ KB

# %%
df.describe()
# Out:
#        country incomeperperson alcconsumption armedforcesrate  \
# count      213             213            213             213
# unique     213             191            181             121
# top       Guam
# freq         1              23             26              49
#
#        breastcancerper100th co2emissions femaleemployrate hivrate  \
# count                   213          213              213     213
# unique                  137          201              154      47
# top
# freq                     40           13               35      66
#
#        internetuserate lifeexpectancy oilperperson polityscore  \
# count              213            213          213         213
# unique             182            180           59          22
# top
# freq                21             22          150          52
#
#        relectricperperson suicideper100th employrate urbanrate
# count                 213             213        213       213
# unique                133             181        140       195
# top
# freq                   77              22         35        10

# %%
df.columns
# Out:
# Index(['country', 'incomeperperson', 'alcconsumption', 'armedforcesrate',
#        'breastcancerper100th', 'co2emissions', 'femaleemployrate', 'hivrate',
#        'internetuserate', 'lifeexpectancy', 'oilperperson', 'polityscore',
#        'relectricperperson', 'suicideper100th', 'employrate', 'urbanrate'],
#       dtype='object')

# %%
df['incomeperperson'] = pd.to_numeric(df['incomeperperson'], errors='coerce')

# %%
df['alcconsumption'] = pd.to_numeric(df['alcconsumption'], errors='coerce')

# %%
df['armedforcesrate'] = pd.to_numeric(df['armedforcesrate'], errors='coerce')

# %%
df['breastcancerper100th'] = pd.to_numeric(df['breastcancerper100th'], errors='coerce')

# %%
df['co2emissions'] = pd.to_numeric(df['co2emissions'], errors='coerce')

# %%
df['femaleemployrate'] = pd.to_numeric(df['femaleemployrate'], errors='coerce')

# %%
df['hivrate'] = pd.to_numeric(df['hivrate'], errors='coerce')

# %%
df['internetuserate'] = pd.to_numeric(df['internetuserate'], errors='coerce')

# %%
df['lifeexpectancy'] = pd.to_numeric(df['lifeexpectancy'], errors='coerce')

# %%
df['oilperperson'] = pd.to_numeric(df['oilperperson'], errors='coerce')

# %%
df['polityscore'] = pd.to_numeric(df['polityscore'], errors='coerce')

# %%
df['relectricperperson'] = pd.to_numeric(df['relectricperperson'], errors='coerce')

# %%
df['suicideper100th'] = pd.to_numeric(df['suicideper100th'], errors='coerce')

# %%
df['employrate'] = pd.to_numeric(df['employrate'], errors='coerce')

# %%
df['urbanrate'] = pd.to_numeric(df['urbanrate'], errors='coerce')

# %%
df.head()
# Out:
#        country  incomeperperson  alcconsumption  armedforcesrate  \
# 0  Afghanistan              NaN            0.03             0.57
# 1      Albania          1915.00            7.29             1.02
# 2      Algeria          2231.99            0.69             2.31
# 3      Andorra         21943.34           10.17              NaN
# 4       Angola          1381.00            5.57             1.46
#
#    breastcancerper100th  co2emissions  femaleemployrate  hivrate  \
# 0                  26.8  7.594400e+07              25.6      NaN
# 1                  57.4  2.237473e+08              42.1      NaN
# 2                  23.5  2.932109e+09              31.7      0.1
# 3                   NaN           NaN               NaN      NaN
# 4                  23.1  2.483580e+08              69.4      2.0
#
#    internetuserate  lifeexpectancy  oilperperson  polityscore  \
# 0             3.65           48.67           NaN          0.0
# 1            44.99           76.92           NaN          9.0
# 2            12.50           73.13          0.42          2.0
# 3            81.00             NaN           NaN          NaN
# 4            10.00           51.09           NaN         -2.0
#
#    relectricperperson  suicideper100th  employrate  urbanrate
# 0                 NaN             6.68        55.7      24.04
# 1              636.34             7.70        51.4      46.72
# 2              590.51             4.85        50.5      65.22
# 3                 NaN             5.36         NaN      88.92
# 4              173.00            14.55        75.7      56.70

# %%
df.hist(figsize=(20,10))
plt.show()

# %%
df.describe()
# Out:
#        incomeperperson  alcconsumption  armedforcesrate  breastcancerper100th  \
# count       190.000000      187.000000       164.000000            173.000000
# mean       8740.965895        6.689412         1.443963             37.402890
# std       14262.809055        4.899617         1.709174             22.697901
# min         103.780000        0.030000         0.000000              3.900000
# 25%         748.245000        2.625000         0.477500             20.600000
# 50%        2553.495000        5.920000         0.930000             30.000000
# 75%        9379.895000        9.925000         1.612500             50.300000
# max      105147.440000       23.010000        10.640000            101.100000
#
#        co2emissions  femaleemployrate     hivrate  internetuserate  \
# count  2.000000e+02        178.000000  147.000000       192.000000
# mean   5.033262e+09         47.549438    1.935442        35.632760
# std    2.573812e+10         14.625743    4.376727        27.780433
# min    1.320000e+05         11.300000    0.060000         0.210000
# 25%    3.484617e+07         38.725000    0.100000        10.000000
# 50%    1.859018e+08         47.550000    0.400000        31.810000
# 75%    1.846084e+09         55.875000    1.300000        56.415000
# max    3.342209e+11         83.300000   25.900000        95.640000
#
#        lifeexpectancy  oilperperson  polityscore  relectricperperson  \
# count      191.000000     63.000000   161.000000          136.000000
# mean        69.753979      1.484603     3.689441         1173.179044
# std          9.708542      1.825321     6.314899         1681.440171
# min         47.790000      0.030000   -10.000000            0.000000
# 25%         64.450000      0.530000    -2.000000          203.647500
# 50%         73.130000      1.030000     6.000000          597.135000
# 75%         76.595000      1.625000     9.000000         1491.147500
# max         83.390000     12.230000    10.000000        11154.760000
#
#        suicideper100th  employrate   urbanrate
# count       191.000000  178.000000  203.000000
# mean          9.640419   58.635955   56.769360
# std           6.299770   10.519455   23.844933
# min           0.200000   32.000000   10.400000
# 25%           4.985000   51.225000   36.830000
# 50%           8.260000   58.700000   57.940000
# 75%          12.330000   64.975000   74.210000
# max          35.750000   83.200000  100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               213 non-null    object
#  1   incomeperperson       190 non-null    float64
#  2   alcconsumption        187 non-null    float64
#  3   armedforcesrate       164 non-null    float64
#  4   breastcancerper100th  173 non-null    float64
#  5   co2emissions          200 non-null    float64
#  6   femaleemployrate      178 non-null    float64
#  7   hivrate               147 non-null    float64
#  8   internetuserate       192 non-null    float64
#  9   lifeexpectancy        191 non-null    float64
#  10  oilperperson          63 non-null     float64
#  11  polityscore           161 non-null    float64
#  12  relectricperperson    136 non-null    float64
#  13  suicideper100th       191 non-null    float64
#  14  employrate            178 non-null    float64
#  15  urbanrate             203 non-null    float64
# dtypes: float64(15), object(1)
# memory usage: 26.8+ KB

# %%
df.to_csv("gapmindercleaned.csv", index=False)
